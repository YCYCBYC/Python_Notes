# %% [markdown]
# # Low Tun Report Data Fill Demo

# %%
## import packages
import pandas as pd
import numpy as np

##  check version
pd.__version__
# Out:
# '1.1.5'

# %%
##  read raw data
data0 = pd.read_csv('LowTurnReportData_20182021.csv', header = 0)

##  copy data1
data1 = data0.copy()

##  set index of data1
data1.set_index('KitSKU', inplace = True)

data1.dtypes
# Out:
# KitName                      object
# InspStat                     object
# SNCount                       int64
# 20202021ShipmentCount         int64
# 20202021PeriodLowTurn       float64
# 20192020ShipmentCount         int64
# 20192020PeriodLowTurn       float64
# 20182019ShipmentCount         int64
# 20182019PeriodLowTurn       float64
# OverallLowTurn              float64
# PotentialStockRedundancy    float64
# RedundantAmount             float64
# Unit                         object
# l                            object
# w                            object
# h                            object
# Space                       float64
# Breakdown                    object
# PSCKits                     float64
# PSCSpaceNeed                float64
# HOUKits                     float64
# HOUSpaceNeed                float64
# TruckUse                    float64
# dtype: object

# %%
## copy data2 for edit
data2 = data1.copy()

# %%
##  judge low turn
data2['20202021PeriodLowTurn'] = np.where(data2['20202021ShipmentCount'] <= 2, 1, 0)
data2['20192020PeriodLowTurn'] = np.where(data2['20192020ShipmentCount'] <= 2, 1, 0)
data2['20182019PeriodLowTurn'] = np.where(data2['20182019ShipmentCount'] <= 2, 1, 0)

##  judge overall low turn
data2['OverallLowTurn'] = np.where( data2['20202021PeriodLowTurn'] + 
                                    data2['20192020PeriodLowTurn'] + 
                                    data2['20182019PeriodLowTurn'] == 3, 1, 0 )

# %%
##  count
print('The kinds of overall low turn kits is: ', (data2['OverallLowTurn'] == 1).sum())
# Out:
# The kinds of overall low turn kits is:  355

# %%
##  potiential redundancy
data2['PotentialStockRedundancy'] = np.where(data2['SNCount'] >= (data2['20202021ShipmentCount']+data2['20182019ShipmentCount'])/2, 1, 0 )

## count
print('The kinds of potential redundancy kits is: ', (data2['PotentialStockRedundancy'] == 1).sum())
# Out:
# The kinds of potential redundancy kits is:  441

# %%
##  cahge type
data2 = data2.astype({  '20202021PeriodLowTurn':int,
                        '20192020PeriodLowTurn':int,
                        '20182019PeriodLowTurn':int,
                        'OverallLowTurn':int,
                        'SNCount':int,
                        '20202021ShipmentCount':int,
                        '20192020ShipmentCount':int,
                        '20182019ShipmentCount':int,
                        'PotentialStockRedundancy':int})

data2.dtypes
# Out:
# KitName                      object
# InspStat                     object
# SNCount                       int32
# 20202021ShipmentCount         int32
# 20202021PeriodLowTurn         int32
# 20192020ShipmentCount         int32
# 20192020PeriodLowTurn         int32
# 20182019ShipmentCount         int32
# 20182019PeriodLowTurn         int32
# OverallLowTurn                int32
# PotentialStockRedundancy      int32
# RedundantAmount             float64
# Unit                         object
# l                            object
# w                            object
# h                            object
# Space                       float64
# Breakdown                    object
# PSCKits                     float64
# PSCSpaceNeed                float64
# HOUKits                     float64
# HOUSpaceNeed                float64
# TruckUse                    float64
# dtype: object

# %%
##  copy data3
data3 = data2.copy()

print(data3)
# Out:
#                                                     KitName   InspStat  \
# KitSKU
# 78029506                           "A" Set Supplemental Kit    General
# 78052118  Tent with 40' Canopy Cover Kit, BigTop 80' x 3...    General
# 7800357   OUT-OF-SHELL COOLER BUNDLE CLEANING KIT WITH 2...  Oil Flush
# 7800100       2300 GPM OIL FILTRATION PUMP WITH DIESEL PUMP  Oil Flush
# 78051606                        8000H Upper Manway Jack Kit      8000H
# ...                                                     ...        ...
# 79007910                   Welder, XMT 350 FieldPro, 4-Pack        NaN
# 79008081            8000H Outer Casing Flipping Bracket Kit        NaN
# 79008085  BB281 LP Rotor Support System Kit for 13.9m2 p...        NaN
# 79008092  SIEMENS KN MAD11 BEARING SEAT ALIGNMENT TOOL; ...        NaN
# 79008210  Siemens KN MAD12/13 Pedestal Stairs (Curley Co...        NaN
#
#           SNCount  20202021ShipmentCount  20202021PeriodLowTurn  \
# KitSKU
# 78029506        3                      0                      1
# 78052118        1                      1                      1
# 7800357         1                      2                      1
# 7800100         1                      2                      1
# 78051606        5                      0                      1
# ...           ...                    ...                    ...
# 79007910        1                      0                      1
# 79008081        1                      0                      1
# 79008085        2                      0                      1
# 79008092        1                      0                      1
# 79008210        1                      0                      1
#
#           20192020ShipmentCount  20192020PeriodLowTurn  20182019ShipmentCount  \
# KitSKU
# 78029506                      0                      1                      0
# 78052118                      1                      1                      0
# 7800357                       1                      1                      0
# 7800100                       2                      1                      1
# 78051606                      0                      1                      0
# ...                         ...                    ...                    ...
# 79007910                      0                      1                      0
# 79008081                      0                      1                      0
# 79008085                      0                      1                      0
# 79008092                      0                      1                      0
# 79008210                      0                      1                      0
#
#           20182019PeriodLowTurn  OverallLowTurn  ...    l    w    h Space  \
# KitSKU                                           ...
# 78029506                      1               1  ...    *    *    *   NaN
# 78052118                      1               1  ...   40    8  9.5   NaN
# 7800357                       1               1  ...  336   96   86   NaN
# 7800100                       1               1  ...  138   54   86   NaN
# 78051606                      1               1  ...   48   24   24   NaN
# ...                         ...             ...  ...  ...  ...  ...   ...
# 79007910                      1               1  ...  NaN  NaN  NaN   NaN
# 79008081                      1               1  ...  NaN  NaN  NaN   NaN
# 79008085                      1               1  ...  NaN  NaN  NaN   NaN
# 79008092                      1               1  ...  NaN  NaN  NaN   NaN
# 79008210                      1               1  ...  NaN  NaN  NaN   NaN
#
#          Breakdown PSCKits  PSCSpaceNeed HOUKits  HOUSpaceNeed  TruckUse
# KitSKU
# 78029506     Split     2.0           NaN     1.0           NaN       NaN
# 78052118     Split     1.0           NaN     0.0           NaN       NaN
# 7800357        PSC     1.0           NaN     NaN           NaN       NaN
# 7800100        PSC     1.0           NaN     NaN           NaN       NaN
# 78051606       PSC     4.0           NaN     NaN           NaN       NaN
# ...            ...     ...           ...     ...           ...       ...
# 79007910       NaN     NaN           NaN     NaN           NaN       NaN
# 79008081       NaN     NaN           NaN     NaN           NaN       NaN
# 79008085       NaN     NaN           NaN     NaN           NaN       NaN
# 79008092       NaN     NaN           NaN     NaN           NaN       NaN
# 79008210       NaN     NaN           NaN     NaN           NaN       NaN
#
# [821 rows x 23 columns]
